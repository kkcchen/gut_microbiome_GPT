# %%
import pandas as pd

# %%
meta_df = pd.read_csv('/home/kevin/Desktop/gut_microbiome/dataset/hmc/sample_metadata.tsv', sep='\t', index_col=0)

# %%
meta_df
# Out:
#                project         srr library_strategy library_source  \
# srs
# DRS193785   PRJDB11894   DRR304700         AMPLICON    METAGENOMIC
# DRS193784   PRJDB11894   DRR304699         AMPLICON    METAGENOMIC
# DRS193783   PRJDB11894   DRR304698         AMPLICON    METAGENOMIC
# DRS193782   PRJDB11894   DRR304697         AMPLICON    METAGENOMIC
# DRS193781   PRJDB11894   DRR304696         AMPLICON    METAGENOMIC
# ...                ...         ...              ...            ...
# SRS672224  PRJNA237362  SRR1534008         AMPLICON    METAGENOMIC
# SRS672203  PRJNA237362  SRR1533989         AMPLICON    METAGENOMIC
# SRS672200  PRJNA237362  SRR1533987         AMPLICON    METAGENOMIC
# SRS672173  PRJNA237362  SRR1533953         AMPLICON    METAGENOMIC
# SRS672144  PRJNA237362  SRR1533924         AMPLICON    METAGENOMIC
#
#                        pubdate  total_bases      instrument geo_loc_name iso  \
# srs
# ...

# %%
set(meta_df.project)
# Out:
# {'PRJDB10485',
#  'PRJDB10527',
#  'PRJDB10528',
#  'PRJDB10612',
#  'PRJDB11845',
#  'PRJDB11894',
#  'PRJDB4360',
#  'PRJDB5316',
#  'PRJDB5564',
#  'PRJDB5678',
#  'PRJDB5791',
#  'PRJDB6499',
#  'PRJDB6804',
#  'PRJDB7891',
#  'PRJDB8027',
#  'PRJDB8511',
#  'PRJDB9239',
#  'PRJDB9469',
#  'PRJDB9705',
#  'PRJDB9936',
#  'PRJDB9975',
#  'PRJEB10326',
#  'PRJEB11419',
#  'PRJEB13896',
#  'PRJEB15481',
#  'PRJEB15534',
#  'PRJEB16344',
#  'PRJEB17608',
#  'PRJEB17610',
#  'PRJEB17613',
#  'PRJEB17860',
#  'PRJEB1799',
#  'PRJEB20766',
#  'PRJEB20773',
#  'PRJEB21946',
#  'PRJEB22676',
#  'PRJEB23775',
#  'PRJEB25853',
#  'PRJEB26012',
#  'PRJEB27068',
#  'PRJEB27564',
#  'PRJEB27662',
#  'PRJEB27807',
#  'PRJEB27868',
#  'PRJEB27978',
#  'PRJEB28159',
#  'PRJEB28700',
#  'PRJEB29433',
#  'PRJEB30292',
#  'PRJEB30401',
#  'PRJEB30495',
#  'PRJEB3079',
#  'PRJEB31155',
#  'PRJEB31354',
#  'PRJEB31775',
#  'PRJEB31840',
#  'PRJEB32077',
#  'PRJEB32244',
#  'PRJEB32537',
# ...
