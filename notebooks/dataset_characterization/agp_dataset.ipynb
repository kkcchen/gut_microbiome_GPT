# %%
import numpy as np

# %%
train_data = np.load('/home/kevin/Desktop/gut_microbiome/dataset/llm_microbiome/microbiomedata/train_encodings_1897.npy')
train_data.shape
# Out:
# (16000, 1897, 2)

# %%
test_data = np.load('/home/kevin/Desktop/gut_microbiome/dataset/llm_microbiome/microbiomedata/test_encodings_1897.npy')
test_data.shape
# Out:
# (2480, 1897, 2)

# %%
train_data[0, :10, 0]
# Out:
# array([ 0.,  1.,  2.,  3.,  4.,  6.,  7.,  8., 12., 19.])
