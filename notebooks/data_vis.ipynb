# %%
import os
import numpy as np
import pandas as pd

# %%
# experimenting with gmrepo dataset
data_path = "../dataset/gmrepo.txt"
df = pd.read_csv(data_path, sep="\t", header=None)
df.columns = ["project_id", "scientific_name", "ncbi_taxon_id", "taxonomic_rank", "LDA", "nr._projects_in_which_this_taxon_is_a_marker"]
df
# Out:
#       project_id               scientific_name  ncbi_taxon_id taxonomic_rank  \
# 0    PRJNA368966                    Prevotella            838          genus
# 1      PRJEB7949                   Eubacterium           1730          genus
# 2      PRJEB7949  Faecalibacterium prausnitzii            853        species
# 3      PRJEB7949              Faecalibacterium         216851          genus
# 4    PRJNA385949                     Alistipes         239759          genus
# ..           ...                           ...            ...            ...
# 279  PRJNA385949                 Streptococcus           1301          genus
# 280  PRJNA385949                       Blautia         572511          genus
# 281  PRJNA368966                 Streptococcus           1301          genus
# 282    PRJEB7949   Parabacteroides goldsteinii         328812        species
# 283    PRJEB7949               Parabacteroides         375288          genus
#
# ...

# %%
# llm_microbiome
import numpy as np
ibd_file = "/home/kevin/Desktop/gut_microbiome/dataset/llm_microbiome/microbiomedata/IBD_train_otu.npy"
ibd_table = np.load(ibd_file)
ibd_table[:10, :200, 0]
# Out:
# array([[0.0000e+00, 1.0000e+00, 2.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [0.0000e+00, 1.0000e+00, 2.0000e+00, ..., 4.1070e+03, 4.1790e+03,
#         4.2410e+03],
#        [0.0000e+00, 1.0000e+00, 2.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        ...,
#        [0.0000e+00, 1.0000e+00, 3.0000e+00, ..., 1.0830e+03, 1.0910e+03,
#         1.0990e+03],
#        [0.0000e+00, 1.0000e+00, 2.0000e+00, ..., 5.7400e+02, 5.7500e+02,
#         5.7600e+02],
#        [0.0000e+00, 1.0000e+00, 2.0000e+00, ..., 1.5271e+04, 1.5669e+04,
#         1.5670e+04]], shape=(10, 200))

# %%
# hmc dataset
import pandas

# %%
hmc_table_path = "/home/kevin/Desktop/gut_microbiome/dataset/hmc/taxonomic_table.csv"
hmc_df = pandas.read_csv(hmc_table_path)
hmc_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 hmc_table_path = "/home/kevin/Desktop/gut_microbiome/dataset/hmc/taxonomic_table.csv"
# ----> 2 hmc_df = pandas.read_csv(hmc_table_path)
#       3 hmc_df.head()
#
# ...
