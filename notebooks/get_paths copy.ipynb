# %%
import pandas as pd
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad

# %%
# pretrain = ad.read_h5ad("/home/kchen/microbiome/gut_microbiome_GPT/datasets/hmc_final/pretrain.h5ad")
# dtrain = ad.read_h5ad("/home/kchen/microbiome/gut_microbiome_GPT/datasets/hmc_final/downstream_train.h5ad")
dtest = ad.read_h5ad("/home/kchen/microbiome/gut_microbiome_GPT/datasets/hmc_final/downstream_test.h5ad")
# Out:
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
dtest.varm["taxonomy"]
# Out:
#                                                       Domain  \
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...  Bacteria
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...  Bacteria
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...  Bacteria
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...  Bacteria
# Bacteria.Bacillota.Bacilli.Erysipelotrichales.E...  Bacteria
# ...                                                      ...
# Bacteria.Marinimicrobia (SAR406 clade).Incertae...  Bacteria
# Bacteria.Balneolota.Balneolia.Balneolales.Balne...  Bacteria
# Bacteria.Pseudomonadota.Gammaproteobacteria.Thi...  Bacteria
# Bacteria.Bacteroidota.Bacteroidia.Flavobacteria...  Bacteria
# Archaea.Halobacteriota.Methanosarcinia.Methanos...   Archaea
#
#                                                                            Phylum  \
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...                 Actinomycetota
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...                 Actinomycetota
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...                 Actinomycetota
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...                 Actinomycetota
# Bacteria.Bacillota.Bacilli.Erysipelotrichales.E...                      Bacillota
# ...                                                                           ...
# Bacteria.Marinimicrobia (SAR406 clade).Incertae...  Marinimicrobia (SAR406 clade)
# Bacteria.Balneolota.Balneolia.Balneolales.Balne...                     Balneolota
# Bacteria.Pseudomonadota.Gammaproteobacteria.Thi...                 Pseudomonadota
# Bacteria.Bacteroidota.Bacteroidia.Flavobacteria...                   Bacteroidota
# Archaea.Halobacteriota.Methanosarcinia.Methanos...                 Halobacteriota
#
#                                                                   Class  \
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...       Coriobacteriia
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...       Coriobacteriia
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...       Coriobacteriia
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...       Coriobacteriia
# Bacteria.Bacillota.Bacilli.Erysipelotrichales.E...              Bacilli
# ...                                                                 ...
# Bacteria.Marinimicrobia (SAR406 clade).Incertae...       Incertae Sedis
# Bacteria.Balneolota.Balneolia.Balneolales.Balne...            Balneolia
# Bacteria.Pseudomonadota.Gammaproteobacteria.Thi...  Gammaproteobacteria
# Bacteria.Bacteroidota.Bacteroidia.Flavobacteria...          Bacteroidia
# Archaea.Halobacteriota.Methanosarcinia.Methanos...      Methanosarcinia
#
#                                                                  Order  \
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...    Coriobacteriales
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...    Coriobacteriales
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...    Coriobacteriales
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...    Coriobacteriales
# Bacteria.Bacillota.Bacilli.Erysipelotrichales.E...  Erysipelotrichales
# ...                                                                ...
# Bacteria.Marinimicrobia (SAR406 clade).Incertae...      Incertae Sedis
# Bacteria.Balneolota.Balneolia.Balneolales.Balne...         Balneolales
# Bacteria.Pseudomonadota.Gammaproteobacteria.Thi...   Thiomicrospirales
# Bacteria.Bacteroidota.Bacteroidia.Flavobacteria...    Flavobacteriales
# Archaea.Halobacteriota.Methanosarcinia.Methanos...   Methanosarcinales
#
#                                                                  Family  \
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...         Atopobiaceae
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...    Coriobacteriaceae
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...      Eggerthellaceae
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...      Eggerthellaceae
# Bacteria.Bacillota.Bacilli.Erysipelotrichales.E...  Erysipelotrichaceae
# ...                                                                 ...
# Bacteria.Marinimicrobia (SAR406 clade).Incertae...       Incertae Sedis
# Bacteria.Balneolota.Balneolia.Balneolales.Balne...         Balneolaceae
# Bacteria.Pseudomonadota.Gammaproteobacteria.Thi...   Thiomicrospiraceae
# Bacteria.Bacteroidota.Bacteroidia.Flavobacteria...    Crocinitomicaceae
# Archaea.Halobacteriota.Methanosarcinia.Methanos...   Methanosarcinaceae
#
#                                                                     Genus
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...  Tractidigestivibacter
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...            Collinsella
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...          Adlercreutzia
# Bacteria.Actinomycetota.Coriobacteriia.Coriobac...       Senegalimassilia
# Bacteria.Bacillota.Bacilli.Erysipelotrichales.E...           Holdemanella
# ...                                                                   ...
# Bacteria.Marinimicrobia (SAR406 clade).Incertae...         Incertae Sedis
# Bacteria.Balneolota.Balneolia.Balneolales.Balne...               Balneola
# Bacteria.Pseudomonadota.Gammaproteobacteria.Thi...         Thiomicrospira
# Bacteria.Bacteroidota.Bacteroidia.Flavobacteria...         Brumimicrobium
# Archaea.Halobacteriota.Methanosarcinia.Methanos...           Methanolobus
#
# [1514 rows x 6 columns]

# %%
X = dtest.X

taxonomy = dtest.varm["taxonomy"]

# 1️⃣ Identify columns belonging to each genus
bacteroides_mask = taxonomy["Genus"] == "Bacteroides"
faecali_mask = taxonomy["Genus"] == "Faecalibacterium"

# Total abundance per sample
bacteroides_vars = np.where(bacteroides_mask)[0]
faecali_vars = np.where(faecali_mask)[0]

total = X.sum(axis=1)
bact = X[:, bacteroides_vars].sum(axis=1)
faec = X[:, faecali_vars].sum(axis=1)

# Avoid divide-by-zero
total = np.clip(total, 1e-8, None)

bact_prop = bact / total
faec_prop = faec / total

has_bact = (bact_prop > 0.05) & (bact_prop < 0.3)
has_faec = (faec_prop > 0.17) & (faec_prop < 0.2)


keep_samples = has_bact & has_faec

dtest_filtered = dtest[keep_samples].copy()

print(f"Kept {keep_samples.sum()} samples")
# Out:
# Kept 128 samples
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
dtest_filtered.obs['study_id']
# Out:
# sample
# PRJEB5729_ERR444058          PRJEB5729
# PRJEB5729_ERR443862          PRJEB5729
# PRJEB5729_ERR443898          PRJEB5729
# PRJEB5729_ERR444115          PRJEB5729
# PRJEB5729_ERR444295          PRJEB5729
#                               ...
# PRJNA428736_SRR6444182     PRJNA428736
# PRJNA428736_SRR6444087     PRJNA428736
# PRJDB10485_DRR243930        PRJDB10485
# PRJDB10485_DRR243847        PRJDB10485
# PRJNA650259_SRR12377168    PRJNA650259
# Name: study_id, Length: 128, dtype: category
# Categories (6, object): ['PRJDB10485', 'PRJEB5729', 'PRJNA428736', 'PRJNA516932', 'PRJNA559143', 'PRJNA650259']

# %%
dtest_filtered.write_h5ad("/home/kchen/microbiome/gut_microbiome_GPT/data/conference/pathway.h5ad")

# %%
dtest_filtered = ad.read_h5ad("/home/kchen/microbiome/gut_microbiome_GPT/data/conference/pathway.h5ad")
# Out:
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
# Go up two levels to project root
project_root = Path.cwd().parents[0]   # = .../gut_microbiome_GPT
# or: project_root = Path.cwd().parent

sys.path.insert(0, str(project_root))

# %%
import sys
from pathlib import Path

from data_utils import TaxaVocabulary

# %%
import torch
embeddings_dict = torch.load('/home/kchen/microbiome/gut_microbiome_GPT/outputs/eval_pathway/pathway_dict.pt')
vocab = TaxaVocabulary.load('/home/kchen/microbiome/gut_microbiome_GPT/outputs/pretrain_mask_gnn/taxa_vocab.pkl')

# %%
X = dtest_filtered.X  # (20, 1514) could be np array or sparse
X.shape
# Out:
# (128, 1514)

# %%
embeddings_dict['taxa_ids'].shape
# Out:
# torch.Size([16, 200])

# %%
outputs = embeddings_dict['outputs'][:,1:,:]

# %%
outputs.shape
# Out:
# torch.Size([16, 200, 128])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import umap

# ----- Prepare X -----
X = dtest_filtered.X
if hasattr(X, "toarray"):
    X_dense = X.toarray()
else:
    X_dense = np.asarray(X)

num_taxa = X_dense.shape[1]

bmask = np.asarray(bacteroides_mask).astype(bool)
fmask = np.asarray(faecali_mask).astype(bool)

# ----- Shared color normalization -----
use_log = True
X_for_scale = np.log1p(X_dense) if use_log else X_dense

vmin, vmax = np.nanpercentile(X_for_scale[X_for_scale > 0], [1, 99])
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
cmap = plt.cm.viridis

print(f"Color scale ({'log1p' if use_log else 'raw'}): vmin={vmin:.4g}, vmax={vmax:.4g}")

# ----- Loop through samples -----
for sample_idx in range(X_dense.shape[0]):

    taxa_ids = embeddings_dict["taxa_ids"][sample_idx].detach().cpu().numpy().astype(int)
    E = outputs[sample_idx].detach().cpu().numpy()

    L = taxa_ids.shape[0]
    row = X_dense[sample_idx]
    row = np.log1p(row) if use_log else row

    # valid taxa indices
    valid = (taxa_ids >= 0) & (taxa_ids < num_taxa)

    # frequency aligned to tokens
    freq = np.zeros(L)
    freq[valid] = row[taxa_ids[valid]]

    # ---- FILTER OUT ZERO FREQUENCY ----
    nonzero = valid & (freq > 0)

    if np.sum(nonzero) == 0:
        print(f"Sample {sample_idx}: no nonzero taxa, skipping.")
        continue

    # labels
    labels = np.full(L, "none", dtype=object)
    labels[nonzero & bmask[taxa_ids]] = "bacteroides"
    labels[nonzero & fmask[taxa_ids]] = "faecalibacterium"

    # UMAP only on remaining tokens
    reducer = umap.UMAP(
        n_neighbors=15,
        min_dist=0.1,
        metric="cosine",
        random_state=0,
    )

    Z = reducer.fit_transform(E[nonzero])

    freq_plot = freq[nonzero]
    labels_plot = labels[nonzero]

    plt.figure(figsize=(7, 5.6))

    # Base scatter
    sc = plt.scatter(
        Z[:, 0], Z[:, 1],
        c=freq_plot,
        s=25,
        alpha=0.9,
        cmap=cmap,
        norm=norm,
        linewidths=0
    )

    # Highlight bacteroides
    m_b = labels_plot == "bacteroides"
    if np.any(m_b):
        plt.scatter(
            Z[m_b, 0], Z[m_b, 1],
            c=freq_plot[m_b],
            s=130,
            cmap=cmap,
            norm=norm,
            edgecolors="black",
            linewidths=1.0,
            zorder=3,
            label="bacteroides"
        )

    # Highlight faecalibacterium
    m_f = labels_plot == "faecalibacterium"
    if np.any(m_f):
        plt.scatter(
            Z[m_f, 0], Z[m_f, 1],
            c=freq_plot[m_f],
            s=150,
            marker="^",
            cmap=cmap,
            norm=norm,
            edgecolors="black",
            linewidths=1.0,
            zorder=4,
            label="faecalibacterium"
        )

    plt.title(f"UMAP of token embeddings (sample {sample_idx})")
    plt.xlabel("UMAP-1")
    plt.ylabel("UMAP-2")

    if np.any(m_b) or np.any(m_f):
        plt.legend()

    cb = plt.colorbar(sc)
    cb.set_label("log1p(freq)" if use_log else "freq")

    plt.tight_layout()
    plt.show()
# Out:
# Color scale (log1p): vmin=1.099, vmax=8.895
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[147], line 31
#      28 # ----- Loop through samples -----
#      29 for sample_idx in range(X_dense.shape[0]):
# ---> 31     taxa_ids = embeddings_dict["taxa_ids"][sample_idx].detach().cpu().numpy().astype(int)
#      32     E = outputs[sample_idx].detach().cpu().numpy()
#      34     L = taxa_ids.shape[0]
#
# IndexError: index 16 is out of bounds for dimension 0 with size 16

# %%
import numpy as np
import matplotlib.pyplot as plt
import umap
from sklearn.cluster import DBSCAN

def cluster_and_plot_one_sample(
    outputs,
    embeddings_dict,
    vocab,
    bacteroides_mask,
    faecali_mask,
    sample_idx: int,
    eps: float = 0.6,
    min_samples: int = 5,
    X=None,                 # optional: dtest_filtered.X (20 x 1514)
    drop_zero_count: bool = False,
    use_log_freq: bool = True,
):
    """
    Cluster token embeddings for a single sample using UMAP -> DBSCAN and plot.

    If X is provided and drop_zero_count=True, tokens whose taxa count is 0 in
    that sample are removed before UMAP/DBSCAN.
    """

    # ---- extract sample ----
    taxa_ids = embeddings_dict["taxa_ids"][sample_idx].detach().cpu().numpy().astype(int)  # (L,)
    E = outputs[sample_idx].detach().cpu().numpy()                                        # (L, d)

    bmask = np.asarray(bacteroides_mask).astype(bool)
    fmask = np.asarray(faecali_mask).astype(bool)

    num_taxa = len(bmask)
    valid = (taxa_ids >= 0) & (taxa_ids < num_taxa)

    # ---- optional: drop zero-count taxa tokens using X ----
    keep = valid.copy()
    freq = None
    if drop_zero_count:
        if X is None:
            raise ValueError("drop_zero_count=True requires X (e.g., dtest_filtered.X).")
        X_dense = X.toarray() if hasattr(X, "toarray") else np.asarray(X)
        row = X_dense[sample_idx]  # (num_taxa,)
        row = np.log1p(row) if use_log_freq else row

        freq = np.full_like(taxa_ids, np.nan, dtype=float)
        freq[valid] = row[taxa_ids[valid]]
        keep = valid & (freq > 0)

        if keep.sum() == 0:
            raise ValueError(f"Sample {sample_idx}: no nonzero-count taxa tokens to plot.")

    # Apply keep-mask
    taxa_ids_k = taxa_ids[keep]
    E_k = E[keep]
    valid_k = (taxa_ids_k >= 0) & (taxa_ids_k < num_taxa)  # should all be True if keep derived from valid

    # highlight masks on kept tokens
    is_b = np.zeros_like(taxa_ids_k, dtype=bool)
    is_f = np.zeros_like(taxa_ids_k, dtype=bool)
    is_b[valid_k] = bmask[taxa_ids_k[valid_k]]
    is_f[valid_k] = fmask[taxa_ids_k[valid_k]]
    is_highlight = is_b | is_f

    # ---- UMAP ----
    reducer = umap.UMAP(
        n_neighbors=15,
        min_dist=0.1,
        metric="cosine",
        random_state=0,
    )
    Z = reducer.fit_transform(E_k)  # (L_kept, 2)

    # ---- DBSCAN ----
    if min_samples < 1:
        raise ValueError("DBSCAN min_samples must be >= 1.")
    clustering = DBSCAN(eps=eps, min_samples=min_samples).fit(Z)
    cluster_labels = clustering.labels_   # -1 = noise

    # clusters containing highlighted taxa
    highlight_clusters = set(cluster_labels[is_highlight])
    highlight_clusters.discard(-1)

    # ---- Plot ----
    plt.figure(figsize=(7, 6))

    unique_clusters = np.unique(cluster_labels)
    colors = plt.cm.tab20(np.linspace(0, 1, len(unique_clusters)))

    for cluster_id, color in zip(unique_clusters, colors):
        m = cluster_labels == cluster_id

        if cluster_id == -1:
            plt.scatter(
                Z[m, 0], Z[m, 1],
                s=8, alpha=0.08,
                label="noise",
                color="gray",
                zorder=1
            )
        else:
            # Slightly emphasize clusters that contain highlights
            alpha = 0.8 if cluster_id in highlight_clusters else 0.45
            plt.scatter(
                Z[m, 0], Z[m, 1],
                s=30, alpha=alpha,
                label=f"cluster {cluster_id}",
                color=color,
                zorder=2
            )

    # Overlay highlighted taxa
    if np.any(is_b):
        plt.scatter(
            Z[is_b, 0], Z[is_b, 1],
            s=120,
            edgecolors="black",
            linewidths=1.0,
            label="Bacteroides",
            zorder=4
        )
    if np.any(is_f):
        plt.scatter(
            Z[is_f, 0], Z[is_f, 1],
            s=120,
            marker="^",
            edgecolors="black",
            linewidths=1.0,
            label="Faecalibacterium",
            zorder=5
        )

    plt.title(f"UMAP + DBSCAN clusters (sample {sample_idx})")
    plt.xlabel("UMAP-1")
    plt.ylabel("UMAP-2")
    plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
    plt.tight_layout()
    plt.show()

    # ---- Extract taxa in highlight clusters ----
    taxa_in_clusters = []
    for cluster_id in highlight_clusters:
        m = cluster_labels == cluster_id
        cluster_taxa_ids = taxa_ids_k[m & valid_k]
        cluster_names = [vocab.id_to_token[int(t)] for t in cluster_taxa_ids]
        taxa_in_clusters.extend(cluster_names)
    taxa_in_clusters = sorted(set(taxa_in_clusters))

    # ---- All clusters dict ----
    all_clusters = {}
    for cluster_id in unique_clusters:
        m = cluster_labels == cluster_id
        cluster_taxa_ids = taxa_ids_k[m & valid_k]
        cluster_names = [vocab.id_to_token[int(t)] for t in cluster_taxa_ids]
        all_clusters[int(cluster_id)] = sorted(set(cluster_names))

    return {
        "sample_idx": int(sample_idx),
        "n_tokens_total": int(len(taxa_ids)),
        "n_tokens_kept": int(len(taxa_ids_k)),
        "highlight_clusters": sorted(list(highlight_clusters)),
        "taxa_in_highlight_clusters": taxa_in_clusters,
        "all_clusters": all_clusters,
    }

# %%
res = cluster_and_plot_one_sample(
    outputs=outputs,
    embeddings_dict=embeddings_dict,
    vocab=vocab,
    bacteroides_mask=bacteroides_mask,
    faecali_mask=faecali_mask,
    sample_idx=11,
    eps=0.6,
    min_samples=5,
    X=dtest_filtered.X,         # optional
    drop_zero_count=True,       # optional
)

print("Clusters containing highlighted taxa:", res["highlight_clusters"])
print("Taxa in those clusters:")
print("\n".join(res["taxa_in_highlight_clusters"][:50]))
# Out:
# /home/kchen/miniconda3/envs/hmbGPT/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Clusters containing highlighted taxa: [3]
# Taxa in those clusters:
# Bacteria.Bacillota.Clostridia.Lachnospirales.Lachnospiraceae.Blautia
# Bacteria.Bacillota.Clostridia.Lachnospirales.Lachnospiraceae.Roseburia
# Bacteria.Bacillota.Clostridia.Oscillospirales.Ruminococcaceae.Faecalibacterium
# Bacteria.Bacillota.Clostridia.Oscillospirales.Ruminococcaceae.Gemmiger
# Bacteria.Bacillota.Clostridia.Oscillospirales.Ruminococcaceae.[Eubacterium] siraeum group
# Bacteria.Bacteroidota.Bacteroidia.Bacteroidales.Bacteroidaceae.Bacteroides
# Bacteria.Bacteroidota.Bacteroidia.Bacteroidales.Rikenellaceae.Alistipes

# %%
res['all_clusters'][3]
# Out:
# ['Bacteria.Bacillota.Clostridia.Lachnospirales.Lachnospiraceae.Blautia',
#  'Bacteria.Bacillota.Clostridia.Lachnospirales.Lachnospiraceae.Roseburia',
#  'Bacteria.Bacillota.Clostridia.Oscillospirales.Ruminococcaceae.Faecalibacterium',
#  'Bacteria.Bacillota.Clostridia.Oscillospirales.Ruminococcaceae.Gemmiger',
#  'Bacteria.Bacillota.Clostridia.Oscillospirales.Ruminococcaceae.[Eubacterium] siraeum group',
#  'Bacteria.Bacteroidota.Bacteroidia.Bacteroidales.Bacteroidaceae.Bacteroides',
#  'Bacteria.Bacteroidota.Bacteroidia.Bacteroidales.Rikenellaceae.Alistipes']

# %%
res['all_clusters'][1]
# Out:
# ['Bacteria.Bacillota.Bacilli.Lactobacillales.Streptococcaceae.Streptococcus',
#  'Bacteria.Bacillota.Clostridia.Lachnospirales.Lachnospiraceae.Anaerobutyricum',
#  'Bacteria.Bacillota.Clostridia.Lachnospirales.Lachnospiraceae.GCA-900066575',
#  'Bacteria.Bacillota.Clostridia.Lachnospirales.Lachnospiraceae.Lachnospira',
#  'Bacteria.Bacillota.Clostridia.Lachnospirales.Lachnospiraceae.Lachnospiraceae ND3007 group',
#  'Bacteria.Bacillota.Clostridia.Lachnospirales.Lachnospiraceae.Lachnospiraceae UCG-010',
#  'Bacteria.Bacillota.Clostridia.Oscillospirales.NA.NA',
#  'Bacteria.Bacillota.Clostridia.Oscillospirales.Oscillospiraceae.UCG-005',
#  'Bacteria.Bacillota.Clostridia.Peptostreptococcales-Tissierellales.Anaerovoracaceae.Family XIII AD3011 group',
#  'Bacteria.Bacillota.Negativicutes.Acidaminococcales.Acidaminococcaceae.Phascolarctobacterium']
